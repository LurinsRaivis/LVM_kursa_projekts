# %%
# %pip install google-genai
# %pip install requests
# Out:
# Requirement already satisfied: google-genai in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (1.51.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.12.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import csv
from google import genai
from google.genai import types 
from dotenv import load_dotenv
import time
import random

# %%
load_dotenv()

client = genai.Client()

# %%
def read_questions(csv_path):
    """Read questions into a dict: {question_number: question_text}"""
    questions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, question = row[0].strip(), row[1].strip()
                questions[num] = question
    return questions

# %%
def read_options(csv_path):
    """Read options into a dict: {question_number: [option1, option2, ...]}"""
    options = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, answer = row[0].strip(), row[1].strip()
                options.setdefault(num, []).append(answer)
    return options

# %%
def read_descriptions(csv_path):
    """Read image descriptions into a dict: {question_number: description_text}"""
    descriptions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, desc = row[0].strip(), row[1].strip()
                descriptions[num] = desc

    
    return descriptions

# %%
def ask_gemini_about_description(description, question, options):
    """Ask Gemini about a textual description of an image"""
    
    system_instruction = (
        "You are a specialized **Latvian traffic rules expert**. "
        "Your entire internal reasoning and final output MUST be conducted **solely in English**."
        "---"
        "**ABSOLUTE OUTPUT REQUIREMENT:**"
        "The **ONLY** output you are permitted to generate is the **exact text of the single correct option in English**."
        "You **MUST NOT** include any reasoning, explanation, numbering, or introductory phrases whatsoever."
        "The output **MUST EXACTLY MATCH** one of the provided options and be nothing else."
    )
    
    prompt_text = (
        f"Description: {description}\n\n"
        f"Question: {question}\n"
        f"Options: {options if options else 'No options provided'}"
    )

    contents = [prompt_text]

    config = types.GenerateContentConfig(
        system_instruction=system_instruction,
        max_output_tokens=500,
        thinking_config=types.ThinkingConfig(thinking_budget=0),    
    )

    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=contents,
            config=config,
        )
        
        if response.text is not None:
            return response.text.strip()
        
        if response.candidates and response.candidates[0].finish_reason:
            reason = response.candidates[0].finish_reason.name
            if response.prompt_feedback and response.prompt_feedback.block_reason:
                block_reason = response.prompt_feedback.block_reason.name
                return f"Blocked: {block_reason} (Finish Reason: {reason})"
            return f"Error: Empty response. Finish Reason: {reason}"
        
        return "Error: Empty response (No reason available)."

    except Exception as e:
        return f"API Call Error: {str(e)}"

# %%
def main():
    descriptions_csv = "descriptions.csv"
    questions_csv = "questions.csv"
    options_csv = "options.csv"

    results_all = []

    descriptions = read_descriptions(descriptions_csv)
    questions = read_questions(questions_csv)
    options = read_options(options_csv)
    
    all_nums = sorted(list(set(descriptions.keys()) & set(questions.keys())))

    random.shuffle(all_nums)


    print(f"Processing {len(all_nums)} descriptions in random order.")
    
    count = 1
    for q_num in all_nums:
        if q_num not in descriptions or q_num not in questions:
            continue
            
        description = descriptions[q_num]
        question = questions[q_num]
        answer_options = options.get(q_num, [])

        print(f"Processing question {q_num}... ({count}/{len(all_nums)})")
        
        answer = ask_gemini_about_description(description, question, answer_options) 
        
        count += 1

        results_all.append({
            "image_number": q_num,
            "model_answer": answer
        })

        print(f"Question {q_num}: {answer}\n")

    output_csv_file = "results_Gemini_description.csv"
    with open(output_csv_file, "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["image_number", "question", "options", "model_answer"]
        )
        writer.writeheader()
        for result in results_all:
            q_num = result["image_number"]
            
            writer.writerow({
                "image_number": q_num,
                "question": questions.get(q_num, ""),
                "options": ";".join(options.get(q_num, [])),
                "model_answer": result["model_answer"]
            })

    print(f"Saved all results to: {output_csv_file}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing 100 descriptions in random order.
# Processing question 37... (1/100)
# Question 37: That road works are being carried out on the road.
#
# Processing question 19... (2/100)
# Question 19: A.
#
# Processing question 93... (3/100)
# Question 93: I will cross first.
#
# Processing question 7... (4/100)
# Question 7: You will give way to the cyclist.
#
# Processing question 79... (5/100)
# Question 79: Cycleway will cross the carriageway.
#
# Processing question 87... (6/100)
# Question 87: I will give way to the cyclist.
#
# Processing question 17... (7/100)
# Question 17: A B.
#
# Processing question 20... (8/100)
# Question 20: A place where parking is prohibited.
#
# Processing question 62... (9/100)
# Question 62: To all.
#
# Processing question 22... (10/100)
# Question 22: You will give way to both car drivers.
#
# Processing question 31... (11/100)
# Question 31: You will give way to both drivers.
#
# Processing question 89... (12/100)
# Question 89: It is allowed.
#
# Processing question 55... (13/100)
# Question 55: Both vehicles are parked incorrectly.
#
# Processing question 68... (14/100)
# Question 68: I will give way to both vehicles.
#
# Processing question 67... (15/100)
# Question 67: I will cross first.
#
# Processing question 11... (16/100)
# Question 11: Only to the right.
#
# Processing question 40... (17/100)
# Question 40: B.
#
# Processing question 60... (18/100)
# Question 60: Green vehicle driver.
#
# Processing question 90... (19/100)
# Question 90: I will only give way to the emergency vehicle.
#
# Processing question 5... (20/100)
# Question 5: Driving at a speed exceeding the one indicated on the sign.
#
# Processing question 96... (21/100)
# Question 96: It is forbidden.
#
# Processing question 14... (22/100)
# Question 14: You will give way to the pedestrian.
#
# Processing question 41... (23/100)
# Question 41: A place where you must stop if necessary to give way to vehicles on the intersecting road.
#
# Processing question 1... (24/100)
# Question 1: Prohibited.
#
# Processing question 50... (25/100)
# Question 50: I will cross first.
#
# Processing question 74... (26/100)
# Question 74: I will cross last.
#
# Processing question 91... (27/100)
# Question 91: To stop.
#
# Processing question 80... (28/100)
# Question 80: It is allowed.
#
# Processing question 97... (29/100)
# Question 97: Only the red vehicle driver.
#
# Processing question 63... (30/100)
# Question 63: That a solid line is ahead.
#
# Processing question 9... (31/100)
# Question 9: You will cross the intersection first.
#
# Processing question 28... (32/100)
# Question 28: Entry for vehicles whose height (with or without load) exceeds 3.5 m.
#
# Processing question 81... (33/100)
# Question 81: The truck and the motorcycle.
#
# Processing question 99... (34/100)
# Question 99: Loose chippings (stones) may be thrown out from under tyres.
#
# Processing question 83... (35/100)
# Question 83: A place where the rules applying to populated areas should be observed.
#
# Processing question 12... (36/100)
# Question 12: You will give way to the driver of the green car.
#
# Processing question 21... (37/100)
# Question 21: Both cars are parked correctly.
#
# Processing question 71... (38/100)
# Question 71: Pedestrian.
#
# Processing question 34... (39/100)
# Question 34: Allowed.
#
# Processing question 18... (40/100)
# Question 18: Neither driver has priority.
#
# Processing question 26... (41/100)
# Question 26: The passenger car driver.
#
# Processing question 72... (42/100)
# Question 72: Immediately stop on the right side of the road.
#
# Processing question 38... (43/100)
# Question 38: Allowed.
#
# Processing question 77... (44/100)
# Question 77: 70 km/h.
#
# Processing question 15... (45/100)
# Question 15: Prohibited.
#
# Processing question 10... (46/100)
# Question 10: In all directions.
#
# Processing question 39... (47/100)
# Question 39: The car driver.
#
# Processing question 82... (48/100)
# Question 82: No.
#
# Processing question 61... (49/100)
# Question 61: Allowed, if the cargo does not interfere with driving and does not disturb other traffic participants
#
# Processing question 36... (50/100)
# Question 36: You will give way to all cars.
#
# Processing question 56... (51/100)
# Question 56: I will cross last.
#
# Processing question 70... (52/100)
# Question 70: Only straight.
#
# Processing question 33... (53/100)
# Question 33: An overpass.
#
# Processing question 78... (54/100)
# Question 78: Beginning of a two-way road
#
# Processing question 13... (55/100)
# Question 13: Prohibited in all cases.
#
# Processing question 85... (56/100)
# Question 85: None of the places.
#
# Processing question 64... (57/100)
# Question 64: I will cross first.
#
# Processing question 53... (58/100)
# Question 53: It is allowed.
#
# Processing question 54... (59/100)
# Question 54: Uneven road ahead (potholes, etc.).
#
# Processing question 69... (60/100)
# Question 69: Bus driver.
#
# Processing question 44... (61/100)
# Question 44: You will cross the intersection first.
#
# Processing question 48... (62/100)
# Question 48: On a non-priority road.
#
# Processing question 2... (63/100)
# Question 2: Prohibited.
#
# Processing question 47... (64/100)
# Question 47: It is forbidden.
#
# Processing question 76... (65/100)
# Question 76: I will cross last.
#
# Processing question 45... (66/100)
# Question 45: Two lanes.
#
# Processing question 94... (67/100)
# Question 94: I will give way to the oncoming vehicle.
#
# Processing question 42... (68/100)
# Question 42: Prohibited in all cases.
#
# Processing question 65... (69/100)
# Question 65: They warn about a road narrowing ahead.
#
# Processing question 95... (70/100)
# Question 95: Give way.
#
# Processing question 58... (71/100)
# Question 58: No.
#
# Processing question 27... (72/100)
# Question 27: You will give way only to the driver of the green car.
#
# Processing question 32... (73/100)
# Question 32: You will cross the intersection last.
#
# Processing question 86... (74/100)
# Question 86: Red vehicle.
#
# Processing question 66... (75/100)
# Question 66: I will give way to both vehicles.
#
# Processing question 59... (76/100)
# Question 59: 50 km/h.
#
# Processing question 3... (77/100)
# Question 3: An intersection.
#
# Processing question 25... (78/100)
# Question 25: C D E.
#
# Processing question 57... (79/100)
# Question 57: To turn left at the intersection.
#
# Processing question 6... (80/100)
# Question 6: On working days from 7:30 till 18:00.
#
# Processing question 73... (81/100)
# Question 73: No.
#
# Processing question 98... (82/100)
# Question 98: 90 km/h.
#
# Processing question 43... (83/100)
# Question 43: As soon as the pedestrian steps onto the cars driving path.
#
# Processing question 46... (84/100)
# Question 46: A vehicle parked under the 'No parking' traffic sign on working days from 8.00 to 20.00 may be evacuated.
#
# Processing question 30... (85/100)
# Question 30: You will turn on the indicator, move into the right lane, and then reduce speed.
#
# Processing question 16... (86/100)
# Question 16: You will immediately reduce your driving speed.
#
# Processing question 24... (87/100)
# Question 24: Prohibited, the shown load must be transported in an appropriate vehicle.
#
# Processing question 51... (88/100)
# Question 51: I will give way to the tram and the automobile.
#
# Processing question 49... (89/100)
# Question 49: I will only give way to the tram.
#
# Processing question 100... (90/100)
# Question 100: Straight, to the right and to the left.
#
# Processing question 29... (91/100)
# Question 29: You will give way to the car driver.
#
# Processing question 75... (92/100)
# Question 75: 50 km/h.
#
# Processing question 23... (93/100)
# Question 23: The bus driver.
#
# Processing question 84... (94/100)
# Question 84: It is forbidden.
#
# Processing question 88... (95/100)
# Question 88: Red vehicle driver.
#
# Processing question 4... (96/100)
# Question 4: No, it would endanger traffic safety.
#
# Processing question 52... (97/100)
# Question 52: I will cross first.
#
# Processing question 35... (98/100)
# Question 35: 30 km/h.
#
# Processing question 92... (99/100)
# Question 92: Yes.
#
# Processing question 8... (100/100)
# Question 8: Prohibited.
#
# Saved all results to: results_Gemini_description.csv
