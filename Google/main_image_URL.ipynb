# %%
# !pip install python-dotenv
# !pip install google-genai
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-genai in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.50.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (2.12.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (2.31.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2023.11.17)

# %%
# %pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (1.51.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.12.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\raivu\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import csv
import requests
from dotenv import load_dotenv
from google import genai
from google.genai import types
import time
import random

# %%
load_dotenv()

client = genai.Client()

# %%
def read_image_urls(csv_path):
    """Read image URLs into a dict: {image_number: image_url}"""
    urls = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            if len(row) >= 2:
                img_num = row[0].strip()
                img_url = row[1].strip()
                urls[img_num] = img_url
    return urls

# %%
def read_questions(csv_path):
    """Read questions into a dict: {image_number: question_text}"""
    questions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, question = row[0].strip(), row[1].strip()
                questions[num] = question
    return questions

# %%
def read_options(csv_path):
    """Read options into a dict: {question_number: [option1, option2, ...]}"""
    options = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, option = row[0].strip(), row[1].strip()
                options.setdefault(num, []).append(option)
    return options

# %%
def ask_gemini_about_image_url(image_url, question, options):
    """Ask Gemini about an image via URL, structured for multimodal input."""
    
    try:
        image_response = requests.get(image_url, timeout=30)
        image_response.raise_for_status()
        
        image_bytes = image_response.content
        
        mime_type = image_response.headers.get('Content-Type', 'image/png') 
        if not mime_type.startswith('image/') and not mime_type.startswith('application/'):
             mime_type = 'image/png'
             
    except requests.exceptions.RequestException as e:
        return f"Error fetching image from URL: {str(e)}"

    
    image_part = types.Part.from_bytes(
        data=image_bytes,
        mime_type=mime_type,
    )

    prompt_text = (
        "Based on the image and your expertise, select the ONE correct option.\n"
        f"Question: {question}\n"
        f"Options: {options if options else 'No options provided'}"
    )
    
    contents = [
        image_part,
        prompt_text
    ]

    system_instruction = (
        "You are a specialized **Latvian traffic rules expert**. "
        "Your response **MUST be conducted solely in English**."
        "Please think before providing your answer. Keep the thought process internal, do not output it. "
        "Your entire purpose is to select the single correct answer from the provided options."
        "---"
        "**ABSOLUTE OUTPUT REQUIREMENT:**"
        "1. The **ONLY** text you are permitted to generate is the **exact text of the single correct option**."
        "2. You **MUST NOT** include any reasoning, explanation, numbering, punctuation, or introductory phrases whatsoever."
        "3. The output must be a single, complete line of text."
    )
        
    config = types.GenerateContentConfig(
        system_instruction=system_instruction,
        max_output_tokens=500
    )

    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash', 
            contents=contents,
            config=config,
        )
        
        if response.text is not None:
            return response.text.strip()
        
        if response.candidates and response.candidates[0].finish_reason:
            reason = response.candidates[0].finish_reason.name
            
            if response.prompt_feedback and response.prompt_feedback.block_reason:
                block_reason = response.prompt_feedback.block_reason.name
                return f"Blocked: {block_reason} (Finish Reason: {reason})"
                
            return f"Error: Empty response. Finish Reason: {reason}"
        
        return "Error: Empty response (No finish reason available)."
        
    except Exception as e:
        return f"Error: {str(e)}"

# %%
def main():
    images_csv = "image_URLs.csv"
    questions_csv = "questions.csv"
    options_csv = "options.csv"

    results_all = []

    image_urls = read_image_urls(images_csv)
    questions = read_questions(questions_csv)
    options = read_options(options_csv)
    
    all_nums = sorted(list(set(image_urls.keys()) & set(questions.keys())))

    random.shuffle(all_nums)

    print(f"Processing {len(all_nums)} images in random order.")
    
    count = 1
    for img_num in all_nums:
        if img_num not in image_urls or img_num not in questions:
            continue
            
        image_url = image_urls[img_num]
        question = questions[img_num]
        answer_options = options.get(img_num, [])

        print(f"Processing image {img_num}... ({count}/{len(all_nums)})")
        
        answer = ask_gemini_about_image_url(image_url, question, answer_options) 
        
        count += 1

        results_all.append({
            "image_number": img_num,
            "model_answer": answer
        })

        print(f"Image {img_num}: {answer}\n")

    output_csv_file = "results_Gemini_image_URL.csv"
    with open(output_csv_file, "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["image_number", "question", "options", "model_answer"]
        )
        writer.writeheader()
        for result in results_all:
            img_num = result["image_number"]
            
            writer.writerow({
                "image_number": img_num,
                "question": questions.get(img_num, ""),
                "options": ";".join(options.get(img_num, [])),
                "model_answer": result["model_answer"]
            })

    print(f"Saved all results to: {output_csv_file}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing 100 images in random order.
# Processing image 3... (1/100)
# Image 3: An intersection.
#
# Processing image 64... (2/100)
# Image 64: I will cross first.
#
# Processing image 26... (3/100)
# Image 26: The passenger car driver.
#
# Processing image 37... (4/100)
# Image 37: That road works are being carried out on the road.
#
# Processing image 50... (5/100)
# Image 50: I will cross first.
#
# Processing image 1... (6/100)
# Image 1: Prohibited.
#
# Processing image 80... (7/100)
# Image 80: It is forbidden.
#
# Processing image 55... (8/100)
# Image 55: Both vehicles are parked incorrectly.
#
# Processing image 75... (9/100)
# Image 75: 50 km/h.
#
# Processing image 73... (10/100)
# Image 73: No.
#
# Processing image 2... (11/100)
# Image 2: Prohibited.
#
# Processing image 30... (12/100)
# Image 30: You will turn on the indicator, move into the right lane, and then reduce speed.
#
# Processing image 93... (13/100)
# Image 93: I will give way to both vehicles.
#
# Processing image 82... (14/100)
# Image 82: No.
#
# Processing image 65... (15/100)
# Image 65: They designate a lane where the driving direction will change to the opposite direction.
#
# Processing image 44... (16/100)
# Image 44: You will give way only to the truck driver.
#
# Processing image 51... (17/100)
# Image 51: I will give way to the tram and the automobile.
#
# Processing image 58... (18/100)
# Image 58: No.
#
# Processing image 38... (19/100)
# Image 38: Allowed.
#
# Processing image 46... (20/100)
# Image 46: A vehicle parked under the 'No parking' traffic sign on working days from 8
#
# Processing image 11... (21/100)
# Image 11: Only to the right.
#
# Processing image 31... (22/100)
# Image 31: You will give way to both drivers.
#
# Processing image 18... (23/100)
# Image 18: The driver of the yellow car.
#
# Processing image 70... (24/100)
# Image 70: Only straight.
#
# Processing image 7... (25/100)
# Image 7: You will give way to the cyclist.
#
# Processing image 41... (26/100)
# Image 41: A place where you must stop if necessary to give way to vehicles on the intersecting road.
#
# Processing image 5... (27/100)
# Image 5: Driving at a speed exceeding the one indicated on the sign.
#
# Processing image 89... (28/100)
# Image 89: It is allowed.
#
# Processing image 23... (29/100)
# Image 23: The passenger car driver.
#
# Processing image 77... (30/100)
# Image 77: 70 km/h.
#
# Processing image 9... (31/100)
# Image 9: You will give way only to the driver of the green car.
#
# Processing image 8... (32/100)
# Image 8: Prohibited.
#
# Processing image 24... (33/100)
# Image 24: Prohibited, the shown load must be transported in an appropriate vehicle.
#
# Processing image 34... (34/100)
# Image 34: Prohibited.
#
# Processing image 36... (35/100)
# Image 36: You will give way to all cars.
#
# Processing image 52... (36/100)
# Image 52: I will give way to the motorcycle and the tram.
#
# Processing image 14... (37/100)
# Image 14: You will give way to the pedestrian.
#
# Processing image 71... (38/100)
# Image 71: Pedestrian.
#
# Processing image 19... (39/100)
# Image 19: A.
#
# Processing image 100... (40/100)
# Image 100: Straight, to the right and to the left.
#
# Processing image 32... (41/100)
# Image 32: You will cross the intersection first.
#
# Processing image 39... (42/100)
# Image 39: The cyclist.
#
# Processing image 94... (43/100)
# Image 94: I will cross first
#
# Processing image 28... (44/100)
# Image 28: Entry for vehicles whose height (with or without load) exceeds 3.5 m.
#
# Processing image 35... (45/100)
# Image 35: 30 km/h.
#
# Processing image 81... (46/100)
# Image 81: The truck and the motorcycle.
#
# Processing image 40... (47/100)
# Image 40: C and B.
#
# Processing image 49... (48/100)
# Image 49: I will give way to the tram and the red vehicle.
#
# Processing image 69... (49/100)
# Image 69: Bus driver.
#
# Processing image 33... (50/100)
# Image 33: An overpass.
#
# Processing image 47... (51/100)
# Image 47: It is forbidden.
#
# Processing image 59... (52/100)
# Image 59: 50 km/h.
#
# Processing image 97... (53/100)
# Image 97: Both drivers
#
# Processing image 92... (54/100)
# Image 92: Yes.
#
# Processing image 62... (55/100)
# Image 62: Only to the pedestrian and the pedestrian pushing the bicycle.
#
# Processing image 96... (56/100)
# Image 96: It is allowed.
#
# Processing image 57... (57/100)
# Image 57: To turn left at the intersection and make a U-turn
#
# Processing image 88... (58/100)
# Image 88: Red vehicle driver.
#
# Processing image 67... (59/100)
# Image 67: I will cross first.
#
# Processing image 87... (60/100)
# Image 87: I will cross first.
#
# Processing image 84... (61/100)
# Image 84: It is forbidden.
#
# Processing image 91... (62/100)
# Image 91: To stop.
#
# Processing image 13... (63/100)
# Image 13: Prohibited in all cases.
#
# Processing image 90... (64/100)
# Image 90: I will give way to both vehicles.
#
# Processing image 43... (65/100)
# Image 43: As soon as the pedestrian begins crossing the pedestrian crossing.
#
# Processing image 98... (66/100)
# Image 98: 90 km/h.
#
# Processing image 72... (67/100)
# Image 72: Immediately stop on the right side of the road.
#
# Processing image 78... (68/100)
# Image 78: Beginning of a two-way road
#
# Processing image 29... (69/100)
# Image 29: You will give way to the car driver.
#
# Processing image 4... (70/100)
# Image 4: No, it would endanger traffic safety.
#
# Processing image 85... (71/100)
# Image 85: None of the places.
#
# Processing image 74... (72/100)
# Image 74: I will cross last.
#
# Processing image 68... (73/100)
# Image 68: I will give way to both vehicles.
#
# Processing image 22... (74/100)
# Image 22: You will give way to both car drivers.
#
# Processing image 83... (75/100)
# Image 83: A place where the rules applying to populated areas should be observed.
#
# Processing image 10... (76/100)
# Image 10: Only to the left.
#
# Processing image 79... (77/100)
# Image 79: Cycleway will cross the carriageway.
#
# Processing image 86... (78/100)
# Image 86: Yellow vehicle.
#
# Processing image 56... (79/100)
# Image 56: I will only give way to the yellow vehicle driver.
#
# Processing image 6... (80/100)
# Image 6: On working days from 7:30 till 18:00.
#
# Processing image 12... (81/100)
# Image 12: You will give way to the driver of the green car.
#
# Processing image 16... (82/100)
# Image 16: You will immediately reduce your driving speed.
#
# Processing image 15... (83/100)
# Image 15: Prohibited.
#
# Processing image 95... (84/100)
# Image 95: Give way.
#
# Processing image 17... (85/100)
# Image 17: B D.
#
# Processing image 25... (86/100)
# Image 25: C D E.
#
# Processing image 53... (87/100)
# Image 53: It is forbidden.
#
# Processing image 99... (88/100)
# Image 99: Loose chippings (stones) may be thrown out from under tyres.
#
# Processing image 76... (89/100)
# Image 76: I will cross first.
#
# Processing image 63... (90/100)
# Image 63: That a solid line is ahead.
#
# Processing image 45... (91/100)
# Image 45: Three lanes.
#
# Processing image 21... (92/100)
# Image 21: Both cars are parked correctly.
#
# Processing image 66... (93/100)
# Image 66: I will give way to both vehicles.
#
# Processing image 48... (94/100)
# Image 48: At an equal priority intersection.
#
# Processing image 27... (95/100)
# Image 27: You will give way to both drivers.
#
# Processing image 54... (96/100)
# Image 54: Several speed bumps ahead.
#
# Processing image 42... (97/100)
# Image 42: Prohibited in all cases.
#
# Processing image 20... (98/100)
# Image 20: A place where parking is prohibited.
#
# Processing image 61... (99/100)
# Image 61: Allowed, if the cargo does not interfere with driving and does not disturb other traffic participants
#
# Processing image 60... (100/100)
# Image 60: Green vehicle driver.
#
# Saved all results to: results_Gemini_image_URL.csv
