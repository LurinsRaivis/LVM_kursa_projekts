# %%
import os
import csv
from dotenv import load_dotenv
from openai import OpenAI
import time
import random

# %%
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def read_questions(csv_path):
    """Read questions into a dict: {question_number: question_text}"""
    questions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, question = row[0].strip(), row[1].strip()
                questions[num] = question
    return questions

# %%
def read_options(csv_path):
    """Read options into a dict: {question_number: [option1, option2, ...]}"""
    options = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, answer = row[0].strip(), row[1].strip()
                options.setdefault(num, []).append(answer)
    return options

# %%
def read_descriptions(csv_path):
    """Read image descriptions into a dict: {question_number: description_text}"""
    descriptions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, desc = row[0].strip(), row[1].strip()
                descriptions[num] = desc

    
    return descriptions

# %%
def ask_gpt4o_about_description(description, question, options):
    """Ask GPT-4o-mini about a textual description of an image"""
    user_content = (
        f"Description: {description}\n\n"
        f"Question: {question}\n"
        f"Options: {options if options else 'No options provided'}"
    )

    messages = [
        {
            "role": "system",
            "content": (
                "Answer as a Latvian traffic rules expert. "
                "Analyze the description and return only the correct answer to the question. "
                "Answer should fully match one of the provided options"
                "Base your answer solely on the description content. "
                "If options exist, choose one. "
            )
        },
        {"role": "user", "content": user_content}
    ]

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            max_tokens=500
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {str(e)}"

# %%
def main():
    questions_csv = "questions.csv"
    options_csv = "options.csv"
    descriptions_csv = "descriptions.csv"
    
    results_all = []

    descriptions = read_descriptions(descriptions_csv)
    questions = read_questions(questions_csv)
    options = read_options(options_csv)

    all_nums = list(set(descriptions.keys()) & set(questions.keys()))

    random.shuffle(all_nums)

    print(f"Processing {len(all_nums)} descriptions in random order.")

    count = 1
    for num in all_nums:
        description_text = descriptions[num]
        question = questions[num]
        answer_options = options.get(num, [])

        print(f"Processing description {num}... ({count}/{len(all_nums)})")
        answer = ask_gpt4o_about_description(description_text, question, answer_options)
        
        count += 1
        
        results_all.append({
            "image_number": num,
            "model_answer": answer
        })

        print(f"Description {num}: {answer}\n")
        time.sleep(1)

    with open("results_OpenAI_description.csv", "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["image_number", "question", "options", "model_answer"]
        )
        writer.writeheader()
        for result in results_all:
            num = result["image_number"]
            writer.writerow({
                "image_number": num,
                "question": questions.get(num, ""),
                "options": ";".join(options.get(num, [])),
                "model_answer": result["model_answer"]
            })

    print("Saved all results to: results_OpenAI_description.csv")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing 100 descriptions in random order.
# Processing description 24... (1/100)
# Description 24: Prohibited, the shown load must be transported in an appropriate vehicle.
#
# Processing description 51... (2/100)
# Description 51: I will give way to the tram and the automobile.
#
# Processing description 18... (3/100)
# Description 18: The driver of the green car.
#
# Processing description 96... (4/100)
# Description 96: It is forbidden.
#
# Processing description 39... (5/100)
# Description 39: The cyclist.
#
# Processing description 93... (6/100)
# Description 93: 'I will give way to both vehicles.'
#
# Processing description 36... (7/100)
# Description 36: You will give way to all cars.
#
# Processing description 20... (8/100)
# Description 20: A place where parking is prohibited.
#
# Processing description 7... (9/100)
# Description 7: You will give way to the cyclist.
#
# Processing description 69... (10/100)
# Description 69: Bus driver.
#
# Processing description 53... (11/100)
# Description 53: It is forbidden.
#
# Processing description 75... (12/100)
# Description 75: 50 km/h.
#
# Processing description 42... (13/100)
# Description 42: Prohibited in all cases.
#
# Processing description 47... (14/100)
# Description 47: It is forbidden.
#
# Processing description 29... (15/100)
# Description 29: You will stop before the Stop sign and wait for the green signal.
#
# Processing description 90... (16/100)
# Description 90: I will only give way to the emergency vehicle.
#
# Processing description 40... (17/100)
# Description 40: 'A.'
#
# Processing description 61... (18/100)
# Description 61: Allowed, if the cargo does not interfere with driving and does not disturb other traffic participants
#
# Processing description 17... (19/100)
# Description 17: B C.
#
# Processing description 65... (20/100)
# Description 65: They warn about a road narrowing ahead.
#
# Processing description 3... (21/100)
# Description 3: An intersection.
#
# Processing description 58... (22/100)
# Description 58: No.
#
# Processing description 88... (23/100)
# Description 88: 'Red vehicle driver.'
#
# Processing description 95... (24/100)
# Description 95: Give way.
#
# Processing description 25... (25/100)
# Description 25: C D E.
#
# Processing description 43... (26/100)
# Description 43: As soon as the pedestrian begins crossing the pedestrian crossing.
#
# Processing description 30... (27/100)
# Description 30: You will turn on the indicator, move into the right lane, and then reduce speed.
#
# Processing description 12... (28/100)
# Description 12: You will give way to the driver of the green car.
#
# Processing description 14... (29/100)
# Description 14: You will give way to the pedestrian.
#
# Processing description 55... (30/100)
# Description 55: Both vehicles are parked incorrectly.
#
# Processing description 91... (31/100)
# Description 91: To stop.
#
# Processing description 9... (32/100)
# Description 9: You will give way to both vehicles.
#
# Processing description 13... (33/100)
# Description 13: Yes, to let passengers get in or out.
#
# Processing description 97... (34/100)
# Description 97: Both drivers
#
# Processing description 99... (35/100)
# Description 99: Loose chippings (stones) may be thrown out from under tyres.
#
# Processing description 10... (36/100)
# Description 10: Only straight and to the left.
#
# Processing description 4... (37/100)
# Description 4: No, it would endanger traffic safety.
#
# Processing description 11... (38/100)
# Description 11: Only to the right.
#
# Processing description 8... (39/100)
# Description 8: Prohibited.
#
# Processing description 26... (40/100)
# Description 26: The passenger car driver.
#
# Processing description 82... (41/100)
# Description 82: No.
#
# Processing description 89... (42/100)
# Description 89: It is forbidden.
#
# Processing description 85... (43/100)
# Description 85: None of the places.
#
# Processing description 22... (44/100)
# Description 22: You will give way to both car drivers.
#
# Processing description 27... (45/100)
# Description 27: You will give way to both drivers.
#
# Processing description 67... (46/100)
# Description 67: I will give way to the tram.
#
# Processing description 16... (47/100)
# Description 16: You will immediately reduce your driving speed.
#
# Processing description 31... (48/100)
# Description 31: You will give way to both drivers.
#
# Processing description 76... (49/100)
# Description 76: 'I will only give way to the motorcycle.'
#
# Processing description 73... (50/100)
# Description 73: No.
#
# Processing description 81... (51/100)
# Description 81: The truck and the yellow vehicle.
#
# Processing description 59... (52/100)
# Description 59: 50 km/h.
#
# Processing description 80... (53/100)
# Description 80: It is allowed.
#
# Processing description 33... (54/100)
# Description 33: An overpass.
#
# Processing description 63... (55/100)
# Description 63: That a solid line is ahead.
#
# Processing description 71... (56/100)
# Description 71: 'Pedestrian.'
#
# Processing description 32... (57/100)
# Description 32: You will give way to the red and blue cars.
#
# Processing description 62... (58/100)
# Description 62: Only to the pedestrian and the pedestrian pushing the bicycle.
#
# Processing description 92... (59/100)
# Description 92: Yes.
#
# Processing description 49... (60/100)
# Description 49: I will give way to the tram and the red vehicle.
#
# Processing description 48... (61/100)
# Description 48: At an equal priority intersection.
#
# Processing description 68... (62/100)
# Description 68: I will give way to both vehicles.
#
# Processing description 66... (63/100)
# Description 66: I will give way to both vehicles.
#
# Processing description 78... (64/100)
# Description 78: Beginning of a two-way road
#
# Processing description 86... (65/100)
# Description 86: 'Yellow vehicle.'
#
# Processing description 6... (66/100)
# Description 6: On working days from 7:30 till 18:00.
#
# Processing description 56... (67/100)
# Description 56: I will cross first.
#
# Processing description 60... (68/100)
# Description 60: Green vehicle driver.
#
# Processing description 64... (69/100)
# Description 64: I will cross first.
#
# Processing description 100... (70/100)
# Description 100: Straight and to the right.
#
# Processing description 94... (71/100)
# Description 94: I will give way to the oncoming vehicle.
#
# Processing description 46... (72/100)
# Description 46: A vehicle parked under the 'No parking' traffic sign on working days from 8.00 to 20.00 may be evacuated.
#
# Processing description 28... (73/100)
# Description 28: Entry for vehicles whose height (with or without load) exceeds 3.5 m.
#
# Processing description 37... (74/100)
# Description 37: That road works are being carried out on the road.
#
# Processing description 87... (75/100)
# Description 87: I will give way to the cyclist.
#
# Processing description 19... (76/100)
# Description 19: A.
#
# Processing description 79... (77/100)
# Description 79: Cycleway will cross the carriageway.
#
# Processing description 38... (78/100)
# Description 38: Prohibited near bus stops.
#
# Processing description 41... (79/100)
# Description 41: A place where you must stop if necessary to give way to vehicles on the intersecting road.
#
# Processing description 54... (80/100)
# Description 54: 'Several speed bumps ahead.'
#
# Processing description 44... (81/100)
# Description 44: You will give way only to the oncoming passenger car.
#
# Processing description 35... (82/100)
# Description 35: 30 km/h.
#
# Processing description 72... (83/100)
# Description 72: Continue driving along the route intended.
#
# Processing description 15... (84/100)
# Description 15: Allowed if the total weight of the vehicles does not exceed 3500 kg.
#
# Processing description 45... (85/100)
# Description 45: Two lanes.
#
# Processing description 34... (86/100)
# Description 34: Allowed.
#
# Processing description 74... (87/100)
# Description 74: I will only give way to the motorcycle.
#
# Processing description 77... (88/100)
# Description 77: 70 km/h.
#
# Processing description 5... (89/100)
# Description 5: Driving at a speed exceeding the one indicated on the sign.
#
# Processing description 83... (90/100)
# Description 83: A place where the rules applying to populated areas should be observed.
#
# Processing description 21... (91/100)
# Description 21: Only the white car.
#
# Processing description 98... (92/100)
# Description 98: 90 km/h.
#
# Processing description 23... (93/100)
# Description 23: The bus driver.
#
# Processing description 84... (94/100)
# Description 84: It is forbidden.
#
# Processing description 50... (95/100)
# Description 50: I will cross first.
#
# Processing description 70... (96/100)
# Description 70: Only straight.
#
# Processing description 57... (97/100)
# Description 57: To turn left at the intersection.
#
# Processing description 52... (98/100)
# Description 52: I will give way to the motorcycle and the tram.
#
# Processing description 1... (99/100)
# Description 1: Prohibited.
#
# Processing description 2... (100/100)
# Description 2: Allowed.
#
# Saved all results to: results_OpenAI_description.csv
