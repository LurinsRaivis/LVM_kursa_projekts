# %%
# !pip install python-dotenv
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.7.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: certifi in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\raivu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import os
import csv
import base64
from dotenv import load_dotenv
from openai import OpenAI
import time
import random

# %%
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def read_image_urls(csv_path):
    """Read image URLs into a dict: {image_number: image_url}"""
    urls = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            if len(row) >= 2:
                img_num = row[0].strip()
                img_url = row[1].strip()
                urls[img_num] = img_url
    return urls

# %%
def read_questions(csv_path):
    """Read questions into a dict: {image_number: question_text}"""
    questions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, question = row[0].strip(), row[1].strip()
                questions[num] = question
    return questions

# %%
def read_options(csv_path):
    """Read options into a dict: {question_number: [option1, option2, ...]}"""
    options = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, option = row[0].strip(), row[1].strip()
                options.setdefault(num, []).append(option)
    return options

# %%
def ask_gpt4o_about_image_url(image_url, question, options):
    """Ask GPT-4o-mini about an image via URL, structured for multimodal input."""

    question_text = (
        f"Question: {question}\n"
        f"Options: {options if options else 'No options provided'}"
    )

    messages = [
        {
            "role": "system",
            "content": (
                "Answer as a Latvian traffic rules expert. "
                "Analyze the image and return only the correct answer to the question. "
                "Answer should fully match one of the provided options. "
                "Base your answer solely on the image content. "
                "If options exist, choose one. "
            )
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": question_text},

                {
                    "type": "image_url",
                    "image_url": {
                        "url": image_url,
                        "detail": "high"
                    },
                },
            ],
        }
    ]

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            max_tokens=500
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {str(e)}"

# %%
def main():
    images_csv = "image_URLs.csv"
    questions_csv = "questions.csv"
    options_csv = "options.csv"

    results_all = []

    image_urls = read_image_urls(images_csv)
    questions = read_questions(questions_csv)
    options = read_options(options_csv)
    
    all_image_nums = sorted(list(set(image_urls.keys()) & set(questions.keys())))
    
    random.shuffle(all_image_nums)

    print(f"\n==============================")
    print(f"Starting sequential processing of {len(all_image_nums)} images.")
    print(f"==============================\n")
    count = 1
    for img_num in all_image_nums:
        image_url = image_urls[img_num]
        question = questions[img_num]
        answer_options = options.get(img_num, [])

        print(f"Processing image {img_num}... ({count}/{len(all_image_nums)})")
        answer = ask_gpt4o_about_image_url(image_url, question, answer_options)
        
        count += 1

        results_all.append({
            "image_number": img_num,
            "question": question,
            "options": answer_options,
            "model_answer": answer
        })

        print(f"Image {img_num}: {answer}\n")
        time.sleep(3)

    with open("results_OpenAI_image_URL.csv", "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["image_number", "question", "options", "model_answer"]
        )
        writer.writeheader()
        for result in results_all:
            img_num = result["image_number"]
            writer.writerow({
                "image_number": img_num,
                "question": questions.get(img_num, ""),
                "options": ";".join(options.get(img_num, [])),
                "model_answer": result["model_answer"]
            })

    print("Saved all results to: results_OpenAI_image_URL.csv")

# %%
if __name__ == "__main__":
    main()
# Out:
# ==============================
# Starting sequential processing of 100 images.
# ==============================
#
# Processing image 10... (1/100)
# Image 10: Only straight and to the left.
#
# Processing image 64... (2/100)
# Image 64: I will cross first.
#
# Processing image 63... (3/100)
# Image 63: That a solid line is ahead.
#
# Processing image 14... (4/100)
# Image 14: You will give way to the pedestrian.
#
# Processing image 31... (5/100)
# Image 31: You will give way to both drivers.
#
# Processing image 21... (6/100)
# Image 21: Only the white car.
#
# Processing image 80... (7/100)
# Image 80: It is forbidden.
#
# Processing image 86... (8/100)
# Image 86: 'Red vehicle.'
#
# Processing image 66... (9/100)
# Image 66: I will give way to both vehicles.
#
# Processing image 51... (10/100)
# Image 51: I will give way to the tram and the automobile.
#
# Processing image 50... (11/100)
# Image 50: I will give way to the tram.
#
# Processing image 18... (12/100)
# Image 18: The driver of the yellow car.
#
# Processing image 72... (13/100)
# Image 72: 'Immediately stop. '
#
# Processing image 23... (14/100)
# Image 23: The bus driver.
#
# Processing image 8... (15/100)
# Image 8: Prohibited.
#
# Processing image 74... (16/100)
# Image 74: I will only give way to the motorcycle.
#
# Processing image 44... (17/100)
# Image 44: You will give way to both vehicles.
#
# Processing image 59... (18/100)
# Image 59: 90 km/h.
#
# Processing image 71... (19/100)
# Image 71: Pedestrian.
#
# Processing image 54... (20/100)
# Image 54: Uneven road ahead (potholes, etc.).
#
# Processing image 19... (21/100)
# Image 19: B.
#
# Processing image 28... (22/100)
# Image 28: Entry for vehicles whose height (with or without load) exceeds 3.5 m.
#
# Processing image 87... (23/100)
# Image 87: I will give way to the cyclist.
#
# Processing image 96... (24/100)
# Image 96: It is forbidden.
#
# Processing image 32... (25/100)
# Image 32: You will give way to the red and blue cars.
#
# Processing image 93... (26/100)
# Image 93: I will give way to both vehicles.
#
# Processing image 26... (27/100)
# Image 26: The passenger car driver.
#
# Processing image 5... (28/100)
# Image 5: Driving at a speed exceeding the one indicated on the sign.
#
# Processing image 69... (29/100)
# Image 69: Bus driver.
#
# Processing image 60... (30/100)
# Image 60: Red vehicle driver.
#
# Processing image 52... (31/100)
# Image 52: I will give way to the motorcycle and the tram.
#
# Processing image 12... (32/100)
# Image 12: You will give way to the driver of the green car.
#
# Processing image 89... (33/100)
# Image 89: It is forbidden.
#
# Processing image 65... (34/100)
# Image 65: They designate a lane where the driving direction will change to the opposite direction.
#
# Processing image 22... (35/100)
# Image 22: You will give way to both car drivers.
#
# Processing image 99... (36/100)
# Image 99: Loose chippings (stones) may be thrown out from under tyres.
#
# Processing image 61... (37/100)
# Image 61: Allowed, if the cargo does not interfere with driving and does not disturb other traffic participants.
#
# Processing image 47... (38/100)
# Image 47: It is forbidden.
#
# Processing image 7... (39/100)
# Image 7: You will give way to the cyclist.
#
# Processing image 78... (40/100)
# Image 78: Beginning of a one-way road.
#
# Processing image 70... (41/100)
# Image 70: Only straight.
#
# Processing image 16... (42/100)
# Image 16: You will immediately reduce your driving speed.
#
# Processing image 29... (43/100)
# Image 29: You will stop before the Stop sign and wait for the green signal.
#
# Processing image 85... (44/100)
# Image 85: Only on the right-hand side.
#
# Processing image 36... (45/100)
# Image 36: You will give way to all cars.
#
# Processing image 94... (46/100)
# Image 94: I will give way to the oncoming vehicle.
#
# Processing image 20... (47/100)
# Image 20: A place where parking is prohibited.
#
# Processing image 46... (48/100)
# Image 46: A vehicle parked under the 'No parking' traffic sign on working days from 8.00 to 20.00 may be evacuated.
#
# Processing image 11... (49/100)
# Image 11: Straight, right, and left.
#
# Processing image 41... (50/100)
# Image 41: A place where you must stop if necessary to give way to vehicles on the intersecting road.
#
# Processing image 75... (51/100)
# Image 75: 50 km/h.
#
# Processing image 81... (52/100)
# Image 81: The truck and the yellow vehicle.
#
# Processing image 49... (53/100)
# Image 49: I will give way to the tram and the red vehicle.
#
# Processing image 67... (54/100)
# Image 67: I will give way to the tram.
#
# Processing image 30... (55/100)
# Image 30: You will turn on the indicator, move into the right lane, and then reduce speed.
#
# Processing image 91... (56/100)
# Image 91: To park.
#
# Processing image 73... (57/100)
# Image 73: No.
#
# Processing image 88... (58/100)
# Image 88: 'You.'
#
# Processing image 3... (59/100)
# Image 3: An intersection.
#
# Processing image 82... (60/100)
# Image 82: No.
#
# Processing image 77... (61/100)
# Image 77: 70 km/h.
#
# Processing image 100... (62/100)
# Image 100: Straight and to the right.
#
# Processing image 95... (63/100)
# Image 95: Give way.
#
# Processing image 43... (64/100)
# Image 43: As soon as the pedestrian begins crossing the pedestrian crossing.
#
# Processing image 1... (65/100)
# Image 1: Prohibited.
#
# Processing image 90... (66/100)
# Image 90: I will give way to both vehicles.
#
# Processing image 39... (67/100)
# Image 39: The cyclist.
#
# Processing image 25... (68/100)
# Image 25: C E.
#
# Processing image 6... (69/100)
# Image 6: On working days from 7:30 till 18:00.
#
# Processing image 40... (70/100)
# Image 40: C and B.
#
# Processing image 68... (71/100)
# Image 68: I will give way to both vehicles.
#
# Processing image 9... (72/100)
# Image 9: You will give way to both vehicles.
#
# Processing image 42... (73/100)
# Image 42: Prohibited in all cases.
#
# Processing image 17... (74/100)
# Image 17: B C.
#
# Processing image 62... (75/100)
# Image 62: To all.
#
# Processing image 79... (76/100)
# Image 79: Cycleway will cross the carriageway.
#
# Processing image 83... (77/100)
# Image 83: A place where the rules applying to populated areas should be observed.
#
# Processing image 92... (78/100)
# Image 92: Yes.
#
# Processing image 97... (79/100)
# Image 97: Only the red vehicle driver.
#
# Processing image 84... (80/100)
# Image 84: It is forbidden.
#
# Processing image 13... (81/100)
# Image 13: Yes, to let passengers get in or out.
#
# Processing image 34... (82/100)
# Image 34: Allowed.
#
# Processing image 27... (83/100)
# Image 27: You will give way to both drivers.
#
# Processing image 53... (84/100)
# Image 53: It is forbidden.
#
# Processing image 45... (85/100)
# Image 45: Two lanes.
#
# Processing image 24... (86/100)
# Image 24: Prohibited, the shown load must be transported in an appropriate vehicle.
#
# Processing image 2... (87/100)
# Image 2: Prohibited.
#
# Processing image 48... (88/100)
# Image 48: At an equal priority intersection.
#
# Processing image 76... (89/100)
# Image 76: I will only give way to the motorcycle.
#
# Processing image 35... (90/100)
# Image 35: 50 km/h.
#
# Processing image 15... (91/100)
# Image 15: Allowed if the total weight of the vehicles does not exceed 3500 kg.
#
# Processing image 33... (92/100)
# Image 33: An overpass.
#
# Processing image 4... (93/100)
# Image 4: No, it would endanger traffic safety.
#
# Processing image 56... (94/100)
# Image 56: I will cross first.
#
# Processing image 55... (95/100)
# Image 55: Both vehicles are parked incorrectly.
#
# Processing image 37... (96/100)
# Image 37: Both of the above answers are correct.
#
# Processing image 58... (97/100)
# Image 58: No.
#
# Processing image 57... (98/100)
# Image 57: To turn left at the intersection and make a U-turn.
#
# Processing image 98... (99/100)
# Image 98: 90 km/h.
#
# Processing image 38... (100/100)
# Image 38: Prohibited where the roadway is crossed by a bicycle path.
#
# Saved all results to: results_OpenAI_image_URL.csv
