# %%
import os
import csv
from dotenv import load_dotenv
import time
import requests
import json
import random

# %%
load_dotenv()

XAI_API_KEY = os.getenv("XAI_API_KEY")

# %%
API_URL = "https://api.x.ai/v1/chat/completions"
MODEL = "grok-2-vision-1212"

HEADERS = {
    "Authorization": f"Bearer {XAI_API_KEY}",
    "Content-Type": "application/json"
}

# %%
def read_questions(csv_path):
    questions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, question = row[0].strip(), row[1].strip()
                questions[num] = question
    return questions

# %%
def read_options(csv_path):
    options = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, answer = row[0].strip(), row[1].strip()
                options.setdefault(num, []).append(answer)
    return options

# %%
def read_descriptions(csv_path):
    descriptions = {}
    with open(csv_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) >= 2:
                num, desc = row[0].strip(), row[1].strip()
                descriptions[num] = desc
    return descriptions

# %%
def ask_grok_about_description(description, question, options_list):

    system_prompt = (
        "You are a specialized Latvian traffic rules expert. "
        "Your entire reasoning and final output MUST be in English.\n"
        "ABSOLUTE OUTPUT REQUIREMENT:\n"
        "- Output ONLY the exact text of the single correct option (in English).\n"
        "- Do NOT include any reasoning, explanations, numbering, quotes, or extra text.\n"
        "- The output must match one of the provided options verbatim."
    )

    user_prompt = (
        f"Description of the image:\n{description}\n\n"
        f"Question:\n{question}\n\n"
        f"Options:\n" + "\n".join(options_list) if options_list else "No options provided"
    )

    payload = {
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        "model": MODEL,
        "temperature": 0.0, # More deterministic answer
        "max_tokens": 500,
        "top_p": 1.0
    }

    try:
        response = requests.post(API_URL, headers=HEADERS, json=payload, timeout=60)
        response.raise_for_status()
        data = response.json()

        answer = data["choices"][0]["message"]["content"].strip()

        answer = answer.strip('"\' \n')
        return answer

    except requests.exceptions.HTTPError as http_err:
        err_detail = response.text
        return f"HTTP Error: {http_err} – {err_detail}"
    except Exception as e:
        return f"API Error: {str(e)}"

# %%
def main():
    descriptions_csv = "descriptions.csv"
    questions_csv    = "questions.csv"
    options_csv      = "options.csv"

    descriptions = read_descriptions(descriptions_csv)
    questions    = read_questions(questions_csv)
    options      = read_options(options_csv)

    all_nums = sorted(set(descriptions.keys()) & set(questions.keys()))

    random.shuffle(all_nums)

    print(f"Processing {len(all_nums)} descriptions in random order.")

    results_all = []

    count = 1
    for q_num in all_nums:
        description = descriptions[q_num]
        question    = questions[q_num]
        answer_opts = options.get(q_num, [])

        print(f"Processing description {q_num}... ({count}/{len(all_nums)})")

        answer = ask_grok_about_description(description, question, answer_opts)

        count += 1

        results_all.append({
            "image_number": q_num,
            "model_answer": answer
        })
        print(f"→ {answer}")

    output_csv_file = "results_Grok_description.csv"
    with open(output_csv_file, "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(
            f, fieldnames=["image_number", "question", "options", "model_answer"]
        )
        writer.writeheader()
        for res in results_all:
            q_num = res["image_number"]
            writer.writerow({
                "image_number": q_num,
                "question": questions.get(q_num, ""),
                "options": "; ".join(options.get(q_num, [])),
                "model_answer": res["model_answer"]
            })

    print(f"\nAll done! Results saved to: {output_csv_file}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing 100 descriptions in random order.
# Processing description 79... (1/100)
# → Cycleway will cross the carriageway.
# Processing description 10... (2/100)
# → Only straight and to the left.
# Processing description 17... (3/100)
# → B D
# Processing description 47... (4/100)
# → It is forbidden.
# Processing description 89... (5/100)
# → It is forbidden.
# Processing description 62... (6/100)
# → To all.
# Processing description 82... (7/100)
# → No.
# Processing description 15... (8/100)
# → Prohibited.
# Processing description 29... (9/100)
# → You will give way to the car driver.
# Processing description 61... (10/100)
# → Allowed, if the cargo does not interfere with driving and does not disturb other traffic participants
# Processing description 48... (11/100)
# → On a priority road.
# Processing description 38... (12/100)
# → Prohibited where the roadway is crossed by a bicycle path.
# Processing description 7... (13/100)
# → You will give way to the cyclist.
# Processing description 56... (14/100)
# → I will cross last.
# Processing description 52... (15/100)
# → I will give way to the tram.
# Processing description 14... (16/100)
# → You will give way to the pedestrian.
# Processing description 98... (17/100)
# → 90 km/h
# Processing description 77... (18/100)
# → 70 km/h
# Processing description 37... (19/100)
# → That road works are being carried out on the road.
# Processing description 20... (20/100)
# → A place where parking is prohibited.
# Processing description 63... (21/100)
# → That a solid line is ahead.
# Processing description 83... (22/100)
# → A place where the rules applying to populated areas should be observed.
# Processing description 93... (23/100)
# → I will give way to both vehicles.
# Processing description 86... (24/100)
# → Yellow vehicle.
# Processing description 90... (25/100)
# → I will only give way to the emergency vehicle.
# Processing description 27... (26/100)
# → You will give way only to the driver of the red car.
# Processing description 40... (27/100)
# → A.
# Processing description 69... (28/100)
# → Bus driver.
# Processing description 57... (29/100)
# → To turn left at the intersection.
# Processing description 50... (30/100)
# → I will cross first.
# Processing description 58... (31/100)
# → No.
# Processing description 66... (32/100)
# → I will give way to both vehicles.
# Processing description 34... (33/100)
# → Prohibited.
# Processing description 49... (34/100)
# → I will give way to the tram and the red vehicle.
# Processing description 72... (35/100)
# → Immediately stop on the right side of the road.
# Processing description 23... (36/100)
# → The bus driver.
# Processing description 53... (37/100)
# → It is forbidden.
# Processing description 21... (38/100)
# → Only the white car.
# Processing description 12... (39/100)
# → You will cross the intersection first.
# Processing description 46... (40/100)
# → A vehicle parked under the 'No parking' traffic sign on working days from 8.00 to 20.00 may be evacuated.
# Processing description 51... (41/100)
# → I will only give way to the tram.
# Processing description 4... (42/100)
# → No, it would endanger traffic safety.
# Processing description 35... (43/100)
# → 30 km/h
# Processing description 70... (44/100)
# → Only straight.
# Processing description 25... (45/100)
# → C D E
# Processing description 18... (46/100)
# → The driver of the green car.
# Processing description 91... (47/100)
# → To stop.
# Processing description 11... (48/100)
# → Only to the right.
# Processing description 45... (49/100)
# → Two lanes.
# Processing description 39... (50/100)
# → The cyclist.
# Processing description 33... (51/100)
# → An overpass.
# Processing description 95... (52/100)
# → Give way.
# Processing description 16... (53/100)
# → You will immediately reduce your driving speed.
# Processing description 1... (54/100)
# → Allowed if visibility in the driving direction is greater than 100m.
# Processing description 71... (55/100)
# → Pedestrian.
# Processing description 30... (56/100)
# → You will reduce speed, turn on the indicator, and then move into the right lane.
# Processing description 31... (57/100)
# → You will give way to both drivers.
# Processing description 85... (58/100)
# → None of the places.
# Processing description 100... (59/100)
# → Only to the right
# Processing description 26... (60/100)
# → The passenger car driver.
# Processing description 75... (61/100)
# → 50 km/h
# Processing description 22... (62/100)
# → You will give way to both car drivers.
# Processing description 60... (63/100)
# → Green vehicle driver.
# Processing description 28... (64/100)
# → Entry for vehicles whose height (with or without load) exceeds 3.5 m.
# Processing description 3... (65/100)
# → An intersection.
# Processing description 19... (66/100)
# → A.
# Processing description 78... (67/100)
# → Beginning of a two-way road
# Processing description 44... (68/100)
# → You will give way only to the oncoming passenger car.
# Processing description 2... (69/100)
# → Prohibited.
# Processing description 92... (70/100)
# → Yes.
# Processing description 65... (71/100)
# → They warn about a road narrowing ahead.
# Processing description 74... (72/100)
# → I will cross last.
# Processing description 42... (73/100)
# → Prohibited in all cases.
# Processing description 36... (74/100)
# → You will give way to all cars.
# Processing description 67... (75/100)
# → I will give way to the tram.
# Processing description 84... (76/100)
# → It is forbidden.
# Processing description 43... (77/100)
# → As soon as the pedestrian steps onto the cars driving path.
# Processing description 68... (78/100)
# → I will give way to both vehicles.
# Processing description 87... (79/100)
# → I will give way to the cyclist.
# Processing description 96... (80/100)
# → It is forbidden.
# Processing description 5... (81/100)
# → Driving at a speed exceeding the one indicated on the sign.
# Processing description 24... (82/100)
# → Prohibited, the shown load must be transported in an appropriate vehicle.
# Processing description 81... (83/100)
# → Motorcycle and the yellow vehicle.
# Processing description 80... (84/100)
# → It is allowed.
# Processing description 8... (85/100)
# → Prohibited.
# Processing description 64... (86/100)
# → I will cross first.
# Processing description 32... (87/100)
# → You will cross the intersection last.
# Processing description 55... (88/100)
# → Yes, only the motorcycle.
# Processing description 9... (89/100)
# → You will cross the intersection first.
# Processing description 76... (90/100)
# → I will cross last.
# Processing description 73... (91/100)
# → No.
# Processing description 88... (92/100)
# → Red vehicle driver.
# Processing description 41... (93/100)
# → A place where you must stop if necessary to give way to vehicles on the intersecting road.
# Processing description 59... (94/100)
# → 50 km/h
# Processing description 99... (95/100)
# → Loose chippings (stones) may be thrown out from under tyres.
# Processing description 54... (96/100)
# → Several speed bumps ahead.
# Processing description 13... (97/100)
# → Yes, to let passengers get in or out.
# Processing description 97... (98/100)
# → Only the red vehicle driver.
# Processing description 6... (99/100)
# → On working days from 7:30 till 18:00.
# Processing description 94... (100/100)
# → I will give way to the oncoming vehicle.
#
# All done! Results saved to: results_Grok_description.csv
